# %%
# Importing libraries

import spacy
from spacy.tokens import DocBin # DocBin used for tokenization
from tqdm import tqdm           # tqdm ---> Tqdm is a Python library that provides fast, extensible progress bars for loops and iterables. It's a simple way to track the advancement of time-intensive tasks
import re                       # re ---> Regex used for text processing/pattern matching

nlp = spacy.blank("en") # load a new spacy model
db = DocBin()           # create a DocBin object

# %%
import json

# Load the training data (json file)

with open("../data/train_annotations.json") as fp:
    train_data = json.load(fp)

train_data
# Out:
# {'classes': ['ORG_YEAR', 'SPORTS_NAME', 'WINNING_POSITION'],
#  'annotations': [['Raleigh Flynn, your outstanding performance in the Equestrian Dressage during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[51, 70, 'SPORTS_NAME'],
#      [82, 86, 'ORG_YEAR'],
#      [130, 133, 'WINNING_POSITION']]}],
#   ['Clifford Hall, your outstanding performance in the Boxing during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[51, 57, 'SPORTS_NAME'],
#      [69, 73, 'ORG_YEAR'],
#      [117, 120, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Rowing, Clifton Hamilton has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 61, 'SPORTS_NAME'],
#      [101, 104, 'WINNING_POSITION'],
#      [121, 125, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Eldridge Simmons, who has made a remarkable achievement by securing the 3rd Position in the Wrestling Freestyle competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[131, 134, 'WINNING_POSITION'],
#      [151, 170, 'SPORTS_NAME'],
#      [184, 189, 'ORG_YEAR']]}],
#   ['Frederick Graves, your outstanding performance in the Water Polo during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[54, 64, 'SPORTS_NAME'],
#      [76, 80, 'ORG_YEAR'],
#      [124, 127, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Frederick Lewis, who has made a remarkable achievement by securing the 2nd Position in the Softball competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 158, 'SPORTS_NAME'],
#      [172, 177, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Swimming, Don Dean has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 63, 'SPORTS_NAME'],
#      [95, 98, 'WINNING_POSITION'],
#      [115, 119, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Karate, Alden Cohen has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 61, 'SPORTS_NAME'],
#      [96, 99, 'WINNING_POSITION'],
#      [116, 120, 'ORG_YEAR']]}],
#   ['Percy Goodwin, your outstanding performance in the Tennis during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[51, 57, 'SPORTS_NAME'],
#      [69, 73, 'ORG_YEAR'],
#      [117, 120, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Clifford Weaver, who has made a remarkable achievement by securing the 1st Position in the Table Tennis competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 162, 'SPORTS_NAME'],
#      [176, 181, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Equestrian Dressage, Julius Caldwell has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [113, 116, 'WINNING_POSITION'],
#      [133, 137, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Rhythmic Gymnastics, Paul Hill has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [107, 110, 'WINNING_POSITION'],
#      [127, 131, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Wade, who has made a remarkable achievement by securing the 1st Position in the Modern Pentathlon competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[126, 129, 'WINNING_POSITION'],
#      [146, 163, 'SPORTS_NAME'],
#      [177, 182, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Basketball, Melvin Butler has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 65, 'SPORTS_NAME'],
#      [102, 105, 'WINNING_POSITION'],
#      [122, 126, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Frederick Clements, who has made a remarkable achievement by securing the 3rd Position in the Softball competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[133, 136, 'WINNING_POSITION'],
#      [153, 161, 'SPORTS_NAME'],
#      [175, 180, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Fencing, Ward Kelley has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 62, 'SPORTS_NAME'],
#      [97, 100, 'WINNING_POSITION'],
#      [117, 121, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Climbing, Henry Rodriguez has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 63, 'SPORTS_NAME'],
#      [102, 105, 'WINNING_POSITION'],
#      [122, 126, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Rowing, Brian Nelson has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 61, 'SPORTS_NAME'],
#      [97, 100, 'WINNING_POSITION'],
#      [117, 121, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Diving, Donald Harris has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 61, 'SPORTS_NAME'],
#      [98, 101, 'WINNING_POSITION'],
#      [118, 122, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Table Tennis, Rodolfo Frank has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [104, 107, 'WINNING_POSITION'],
#      [124, 128, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Basketball, Horace Bishop has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 65, 'SPORTS_NAME'],
#      [102, 105, 'WINNING_POSITION'],
#      [122, 126, 'ORG_YEAR']]}],
#   ['Raleigh Gray, your outstanding performance in the Weightlifting during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[50, 63, 'SPORTS_NAME'],
#      [75, 79, 'ORG_YEAR'],
#      [123, 126, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Softball, Russell Bennett has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 63, 'SPORTS_NAME'],
#      [102, 105, 'WINNING_POSITION'],
#      [122, 126, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Judo, Abraham Lyons has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 59, 'SPORTS_NAME'],
#      [96, 99, 'WINNING_POSITION'],
#      [116, 120, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Percy Burgess, who has made a remarkable achievement by securing the 2nd Position in the Rowing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 154, 'SPORTS_NAME'],
#      [168, 173, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Raleigh Owen, who has made a remarkable achievement by securing the 2nd Position in the Weightlifting competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 160, 'SPORTS_NAME'],
#      [174, 179, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Hollis Howell, who has made a remarkable achievement by securing the 1st Position in the Marathon Swimming competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 165, 'SPORTS_NAME'],
#      [179, 184, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Canoe Sprint, Lance Mason has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [102, 105, 'WINNING_POSITION'],
#      [122, 126, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Mountain Bike, Willis Waller has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 68, 'SPORTS_NAME'],
#      [105, 108, 'WINNING_POSITION'],
#      [125, 129, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Dexter Perez, who has made a remarkable achievement by securing the 3rd Position in the Baseball competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 155, 'SPORTS_NAME'],
#      [169, 174, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Handball, Antoine Leonard has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 63, 'SPORTS_NAME'],
#      [102, 105, 'WINNING_POSITION'],
#      [122, 126, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Raleigh Wilkins, who has made a remarkable achievement by securing the 1st Position in the Weightlifting competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 163, 'SPORTS_NAME'],
#      [177, 182, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Ferdinand Hoffman, who has made a remarkable achievement by securing the 1st Position in the Freestyle BMX competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[132, 135, 'WINNING_POSITION'],
#      [152, 165, 'SPORTS_NAME'],
#      [179, 184, 'ORG_YEAR']]}],
#   ['Bertram Hester, your outstanding performance in the Rhythmic Gymnastics during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[52, 71, 'SPORTS_NAME'],
#      [83, 87, 'ORG_YEAR'],
#      [131, 134, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Johnston, who has made a remarkable achievement by securing the 1st Position in the Tennis competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 156, 'SPORTS_NAME'],
#      [170, 175, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Rowing, Perry McLaughlin has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 61, 'SPORTS_NAME'],
#      [101, 104, 'WINNING_POSITION'],
#      [121, 125, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Raleigh Lloyd, who has made a remarkable achievement by securing the 2nd Position in the Basketball competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 158, 'SPORTS_NAME'],
#      [172, 177, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Rugby Sevens, Davis Waters has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [103, 106, 'WINNING_POSITION'],
#      [123, 127, 'ORG_YEAR']]}],
#   ['Clifford Hess, your outstanding performance in the Mountain Bike during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[51, 64, 'SPORTS_NAME'],
#      [76, 80, 'ORG_YEAR'],
#      [124, 127, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Rhythmic Gymnastics, Irving Curry has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [110, 113, 'WINNING_POSITION'],
#      [130, 134, 'ORG_YEAR']]}],
#   ['Irving Francis, your outstanding performance in the Golf during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[52, 56, 'SPORTS_NAME'],
#      [68, 72, 'ORG_YEAR'],
#      [116, 119, 'WINNING_POSITION']]}],
#   ['Roland Langley, your outstanding performance in the Triathlon during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[52, 61, 'SPORTS_NAME'],
#      [73, 77, 'ORG_YEAR'],
#      [121, 124, 'WINNING_POSITION']]}],
#   ['Clifford Edwards, your outstanding performance in the Archery during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[54, 61, 'SPORTS_NAME'],
#      [73, 77, 'ORG_YEAR'],
#      [121, 124, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Percy Cunningham, who has made a remarkable achievement by securing the 3rd Position in the Freestyle BMX competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[131, 134, 'WINNING_POSITION'],
#      [151, 164, 'SPORTS_NAME'],
#      [178, 183, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Table Tennis, Otis Elliott has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [103, 106, 'WINNING_POSITION'],
#      [123, 127, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Artistic Swimming, Thaddeus Harmon has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 72, 'SPORTS_NAME'],
#      [111, 114, 'WINNING_POSITION'],
#      [131, 135, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Frederick Dunn, who has made a remarkable achievement by securing the 3rd Position in the Water Polo competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 159, 'SPORTS_NAME'],
#      [173, 178, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Dexter Bridges, who has made a remarkable achievement by securing the 2nd Position in the Hockey competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 155, 'SPORTS_NAME'],
#      [169, 174, 'ORG_YEAR']]}],
#   ['Percy Finch, your outstanding performance in the Canoe Sprint during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[49, 61, 'SPORTS_NAME'],
#      [73, 77, 'ORG_YEAR'],
#      [121, 124, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Freestyle BMX, Louis Lewis has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 68, 'SPORTS_NAME'],
#      [103, 106, 'WINNING_POSITION'],
#      [123, 127, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Percy Decker, who has made a remarkable achievement by securing the 3rd Position in the Rowing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 153, 'SPORTS_NAME'],
#      [167, 172, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Eldridge Wilkinson, who has made a remarkable achievement by securing the 1st Position in the Wrestling Freestyle competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[133, 136, 'WINNING_POSITION'],
#      [153, 172, 'SPORTS_NAME'],
#      [186, 191, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Artistic Gymnastics, Benedict Andrews has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [114, 117, 'WINNING_POSITION'],
#      [134, 138, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Marathon Swimming, Nelson Chandler has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 72, 'SPORTS_NAME'],
#      [111, 114, 'WINNING_POSITION'],
#      [131, 135, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Sailing, Percy Daniels has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 62, 'SPORTS_NAME'],
#      [99, 102, 'WINNING_POSITION'],
#      [119, 123, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Percy Rhodes, who has made a remarkable achievement by securing the 3rd Position in the Freestyle BMX competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 160, 'SPORTS_NAME'],
#      [174, 179, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Athletics, David Jones has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 64, 'SPORTS_NAME'],
#      [99, 102, 'WINNING_POSITION'],
#      [119, 123, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Montgomery, who has made a remarkable achievement by securing the 2nd Position in the Modern Pentathlon competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[132, 135, 'WINNING_POSITION'],
#      [152, 169, 'SPORTS_NAME'],
#      [183, 188, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Mountain Bike, Johnny Burke has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 68, 'SPORTS_NAME'],
#      [104, 107, 'WINNING_POSITION'],
#      [124, 128, 'ORG_YEAR']]}],
#   ['Percy Joyce, your outstanding performance in the Freestyle BMX during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[49, 62, 'SPORTS_NAME'],
#      [74, 78, 'ORG_YEAR'],
#      [122, 125, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Eldridge Douglas, who has made a remarkable achievement by securing the 3rd Position in the Surfing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[131, 134, 'WINNING_POSITION'],
#      [151, 158, 'SPORTS_NAME'],
#      [172, 177, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Canoe Slalom, Edwin Hawkins has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [104, 107, 'WINNING_POSITION'],
#      [124, 128, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Dexter Meyer, who has made a remarkable achievement by securing the 2nd Position in the Hockey competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 153, 'SPORTS_NAME'],
#      [167, 172, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Rhythmic Gymnastics, Hiram Walters has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [111, 114, 'WINNING_POSITION'],
#      [131, 135, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Raleigh Cox, who has made a remarkable achievement by securing the 3rd Position in the Equestrian Dressage competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[126, 129, 'WINNING_POSITION'],
#      [146, 165, 'SPORTS_NAME'],
#      [179, 184, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Athletics, Ralph Baxter has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 64, 'SPORTS_NAME'],
#      [100, 103, 'WINNING_POSITION'],
#      [120, 124, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Peterson, who has made a remarkable achievement by securing the 3rd Position in the BMX Cycling competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 161, 'SPORTS_NAME'],
#      [175, 180, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Irving Romero, who has made a remarkable achievement by securing the 3rd Position in the Rugby Sevens competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 160, 'SPORTS_NAME'],
#      [174, 179, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Bertram Cameron, who has made a remarkable achievement by securing the 2nd Position in the Taekwondo competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 159, 'SPORTS_NAME'],
#      [173, 178, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Boxing, Otis Bradford has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 61, 'SPORTS_NAME'],
#      [98, 101, 'WINNING_POSITION'],
#      [118, 122, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Badminton, Herbert Morris has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 64, 'SPORTS_NAME'],
#      [102, 105, 'WINNING_POSITION'],
#      [122, 126, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Frederick Dickerson, who has made a remarkable achievement by securing the 3rd Position in the Skateboarding competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[134, 137, 'WINNING_POSITION'],
#      [154, 167, 'SPORTS_NAME'],
#      [181, 186, 'ORG_YEAR']]}],
#   ['Irving Kim, your outstanding performance in the Rugby Sevens during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[48, 60, 'SPORTS_NAME'],
#      [72, 76, 'ORG_YEAR'],
#      [120, 123, 'WINNING_POSITION']]}],
#   ['Eldridge Howell, your outstanding performance in the Wrestling Freestyle during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[53, 72, 'SPORTS_NAME'],
#      [84, 88, 'ORG_YEAR'],
#      [132, 135, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Cycling Road, Solomon Hull has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [103, 106, 'WINNING_POSITION'],
#      [123, 127, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey McDaniel, who has made a remarkable achievement by securing the 2nd Position in the Equestrian Jumping competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 168, 'SPORTS_NAME'],
#      [182, 187, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Horton, who has made a remarkable achievement by securing the 1st Position in the Judo competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 152, 'SPORTS_NAME'],
#      [166, 171, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Sailing, Daryl Welch has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 62, 'SPORTS_NAME'],
#      [97, 100, 'WINNING_POSITION'],
#      [117, 121, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Equestrian Dressage, Emery Jennings has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [112, 115, 'WINNING_POSITION'],
#      [132, 136, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Irvin Hudson, who has made a remarkable achievement by securing the 1st Position in the Mountain Bike competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 160, 'SPORTS_NAME'],
#      [174, 179, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Raleigh Robbins, who has made a remarkable achievement by securing the 3rd Position in the Karate competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 156, 'SPORTS_NAME'],
#      [170, 175, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Jonas King, who has made a remarkable achievement by securing the 1st Position in the Wrestling Freestyle competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[125, 128, 'WINNING_POSITION'],
#      [145, 164, 'SPORTS_NAME'],
#      [178, 183, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Irving Church, who has made a remarkable achievement by securing the 3rd Position in the Athletics competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 157, 'SPORTS_NAME'],
#      [171, 176, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Water Polo, Sheldon Owen has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 65, 'SPORTS_NAME'],
#      [101, 104, 'WINNING_POSITION'],
#      [121, 125, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Bertram Rodgers, who has made a remarkable achievement by securing the 3rd Position in the Rhythmic Gymnastics competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 169, 'SPORTS_NAME'],
#      [183, 188, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Equestrian Jumping, Quentin Weber has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 73, 'SPORTS_NAME'],
#      [110, 113, 'WINNING_POSITION'],
#      [130, 134, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Sport Climbing, Duncan Wiley has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[61, 69, 'SPORTS_NAME'],
#      [105, 108, 'WINNING_POSITION'],
#      [125, 129, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Simpson, who has made a remarkable achievement by securing the 3rd Position in the Wrestling Greco-Roman competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 170, 'SPORTS_NAME'],
#      [184, 189, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Eldridge Thomas, who has made a remarkable achievement by securing the 1st Position in the Equestrian Eventing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 169, 'SPORTS_NAME'],
#      [183, 188, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Irving Medina, who has made a remarkable achievement by securing the 2nd Position in the Golf competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 152, 'SPORTS_NAME'],
#      [166, 171, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Climbing, Leroy Brock has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 63, 'SPORTS_NAME'],
#      [98, 101, 'WINNING_POSITION'],
#      [118, 122, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Surfing, Rudolph Ryan has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 62, 'SPORTS_NAME'],
#      [98, 101, 'WINNING_POSITION'],
#      [118, 122, 'ORG_YEAR']]}],
#   ['Frederick Gutierrez, your outstanding performance in the Softball during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[57, 65, 'SPORTS_NAME'],
#      [77, 81, 'ORG_YEAR'],
#      [125, 128, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Williams, who has made a remarkable achievement by securing the 1st Position in the Wrestling Greco-Roman competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 171, 'SPORTS_NAME'],
#      [185, 190, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Roland Barnett, who has made a remarkable achievement by securing the 2nd Position in the Cycling Road competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 161, 'SPORTS_NAME'],
#      [175, 180, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Football, Eugene Myers has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 63, 'SPORTS_NAME'],
#      [99, 102, 'WINNING_POSITION'],
#      [119, 123, 'ORG_YEAR']]}],
#   ['Bertram Hamilton, your outstanding performance in the Canoe Slalom during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[54, 66, 'SPORTS_NAME'],
#      [78, 82, 'ORG_YEAR'],
#      [126, 129, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Abbott, who has made a remarkable achievement by securing the 2nd Position in the BMX Cycling competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 159, 'SPORTS_NAME'],
#      [173, 178, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Athletics, Carroll Reed has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 64, 'SPORTS_NAME'],
#      [100, 103, 'WINNING_POSITION'],
#      [120, 124, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Jonas Henry, who has made a remarkable achievement by securing the 1st Position in the Fencing competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[126, 129, 'WINNING_POSITION'],
#      [146, 153, 'SPORTS_NAME'],
#      [167, 172, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Weightlifting, Clifford Wade has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 68, 'SPORTS_NAME'],
#      [105, 108, 'WINNING_POSITION'],
#      [125, 129, 'ORG_YEAR']]}],
#   ['Clifford Holt, your outstanding performance in the Table Tennis during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[51, 63, 'SPORTS_NAME'],
#      [75, 79, 'ORG_YEAR'],
#      [123, 126, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Taekwondo, Vincent Green has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 64, 'SPORTS_NAME'],
#      [101, 104, 'WINNING_POSITION'],
#      [121, 125, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Badminton, Charles Brown has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 64, 'SPORTS_NAME'],
#      [101, 104, 'WINNING_POSITION'],
#      [121, 125, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Weightlifting, Ward Floyd has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 68, 'SPORTS_NAME'],
#      [102, 105, 'WINNING_POSITION'],
#      [122, 126, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Canoe Slalom, Roland Salazar has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [105, 108, 'WINNING_POSITION'],
#      [125, 129, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Frederick Stephens, who has made a remarkable achievement by securing the 1st Position in the Softball competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[133, 136, 'WINNING_POSITION'],
#      [153, 161, 'SPORTS_NAME'],
#      [175, 180, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Jonas Hamilton, who has made a remarkable achievement by securing the 1st Position in the Climbing competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 157, 'SPORTS_NAME'],
#      [171, 176, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Sailing, Theodore Vasquez has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 62, 'SPORTS_NAME'],
#      [102, 105, 'WINNING_POSITION'],
#      [122, 126, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Percy Schwartz, who has made a remarkable achievement by securing the 3rd Position in the Tennis competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 155, 'SPORTS_NAME'],
#      [169, 174, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Marathon Swimming, Israel Wagner has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 72, 'SPORTS_NAME'],
#      [109, 112, 'WINNING_POSITION'],
#      [129, 133, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Irving Wolfe, who has made a remarkable achievement by securing the 2nd Position in the Athletics competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 156, 'SPORTS_NAME'],
#      [170, 175, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Percy Powell, who has made a remarkable achievement by securing the 3rd Position in the Canoe Sprint competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 159, 'SPORTS_NAME'],
#      [173, 178, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Triathlon, Isaiah McCoy has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 64, 'SPORTS_NAME'],
#      [100, 103, 'WINNING_POSITION'],
#      [120, 124, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Wilbert Jacobs, who has made a remarkable achievement by securing the 1st Position in the Sport Climbing competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [155, 163, 'SPORTS_NAME'],
#      [177, 182, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Trampoline Gymnastics, Carroll Ray has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 76, 'SPORTS_NAME'],
#      [111, 114, 'WINNING_POSITION'],
#      [131, 135, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Roland Murphy, who has made a remarkable achievement by securing the 2nd Position in the Sailing competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 155, 'SPORTS_NAME'],
#      [169, 174, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Dexter Dunlap, who has made a remarkable achievement by securing the 3rd Position in the Volleyball competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 158, 'SPORTS_NAME'],
#      [172, 177, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Clifford Lowe, who has made a remarkable achievement by securing the 2nd Position in the Boxing competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 154, 'SPORTS_NAME'],
#      [168, 173, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Clifford Stone, who has made a remarkable achievement by securing the 1st Position in the Boxing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 155, 'SPORTS_NAME'],
#      [169, 174, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Fencing, Patrick Sullivan has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 62, 'SPORTS_NAME'],
#      [102, 105, 'WINNING_POSITION'],
#      [122, 126, 'ORG_YEAR']]}],
#   ['Irving Fisher, your outstanding performance in the Climbing during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[51, 59, 'SPORTS_NAME'],
#      [71, 75, 'ORG_YEAR'],
#      [119, 122, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Clifford Sims, who has made a remarkable achievement by securing the 1st Position in the Archery competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 155, 'SPORTS_NAME'],
#      [169, 174, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Beach Volleyball, Lucas Ross has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 71, 'SPORTS_NAME'],
#      [105, 108, 'WINNING_POSITION'],
#      [125, 129, 'ORG_YEAR']]}],
#   ['Raleigh Howard, your outstanding performance in the Weightlifting during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[52, 65, 'SPORTS_NAME'],
#      [77, 81, 'ORG_YEAR'],
#      [125, 128, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Artistic Gymnastics, Dennis Cooper has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [111, 114, 'WINNING_POSITION'],
#      [131, 135, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Roland Dennis, who has made a remarkable achievement by securing the 3rd Position in the Sailing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 155, 'SPORTS_NAME'],
#      [169, 174, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Dawson, who has made a remarkable achievement by securing the 3rd Position in the Modern Pentathlon competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 165, 'SPORTS_NAME'],
#      [179, 184, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Frederick Beck, who has made a remarkable achievement by securing the 2nd Position in the Diving competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 155, 'SPORTS_NAME'],
#      [169, 174, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Canoe Sprint, George Thomas has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [104, 107, 'WINNING_POSITION'],
#      [124, 128, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Sport Climbing, Jordan Turner has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[61, 69, 'SPORTS_NAME'],
#      [106, 109, 'WINNING_POSITION'],
#      [126, 130, 'ORG_YEAR']]}],
#   ['Eldridge Johnston, your outstanding performance in the Equestrian Eventing during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [86, 90, 'ORG_YEAR'],
#      [134, 137, 'WINNING_POSITION']]}],
#   ['Eldridge Fuller, your outstanding performance in the Marathon Swimming during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[53, 70, 'SPORTS_NAME'],
#      [82, 86, 'ORG_YEAR'],
#      [130, 133, 'WINNING_POSITION']]}],
#   ['Roland Graham, your outstanding performance in the Triathlon during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[51, 60, 'SPORTS_NAME'],
#      [72, 76, 'ORG_YEAR'],
#      [120, 123, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Trampoline Gymnastics, Elton Winters has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 76, 'SPORTS_NAME'],
#      [113, 116, 'WINNING_POSITION'],
#      [133, 137, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Dexter Hernandez, who has made a remarkable achievement by securing the 1st Position in the Football competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[131, 134, 'WINNING_POSITION'],
#      [151, 159, 'SPORTS_NAME'],
#      [173, 178, 'ORG_YEAR']]}],
#   ['Irving Erickson, your outstanding performance in the Athletics during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[53, 62, 'SPORTS_NAME'],
#      [74, 78, 'ORG_YEAR'],
#      [122, 125, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Irving Delgado, who has made a remarkable achievement by securing the 3rd Position in the Rugby Sevens competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 161, 'SPORTS_NAME'],
#      [175, 180, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Golf, Christopher Young has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 59, 'SPORTS_NAME'],
#      [100, 103, 'WINNING_POSITION'],
#      [120, 124, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Dexter Olson, who has made a remarkable achievement by securing the 2nd Position in the Volleyball competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 157, 'SPORTS_NAME'],
#      [171, 176, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Clifford McDonald, who has made a remarkable achievement by securing the 2nd Position in the Fencing competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[132, 135, 'WINNING_POSITION'],
#      [152, 159, 'SPORTS_NAME'],
#      [173, 178, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Clifford Arnold, who has made a remarkable achievement by securing the 2nd Position in the Boxing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 156, 'SPORTS_NAME'],
#      [170, 175, 'ORG_YEAR']]}],
# ...
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 168, 'SPORTS_NAME'],
#      [182, 187, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Dexter Diaz, who has made a remarkable achievement by securing the 3rd Position in the Shooting competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[126, 129, 'WINNING_POSITION'],
#      [146, 154, 'SPORTS_NAME'],
#      [168, 173, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Irving Barker, who has made a remarkable achievement by securing the 2nd Position in the Climbing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 156, 'SPORTS_NAME'],
#      [170, 175, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Cycling Track, Ellis Bishop has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 68, 'SPORTS_NAME'],
#      [104, 107, 'WINNING_POSITION'],
#      [124, 128, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Julius Franklin, who has made a remarkable achievement by securing the 1st Position in the Archery competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 157, 'SPORTS_NAME'],
#      [171, 176, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Hockey, Augustus Logan has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 61, 'SPORTS_NAME'],
#      [99, 102, 'WINNING_POSITION'],
#      [119, 123, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Irving Lawson, who has made a remarkable achievement by securing the 2nd Position in the Athletics competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 157, 'SPORTS_NAME'],
#      [171, 176, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Bertram Paul, who has made a remarkable achievement by securing the 3rd Position in the Artistic Gymnastics competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 166, 'SPORTS_NAME'],
#      [180, 185, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Roland Pratt, who has made a remarkable achievement by securing the 3rd Position in the Cycling Road competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 159, 'SPORTS_NAME'],
#      [173, 178, 'ORG_YEAR']]}],
#   ['Roland Guerrero, your outstanding performance in the Badminton during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[53, 62, 'SPORTS_NAME'],
#      [74, 78, 'ORG_YEAR'],
#      [122, 125, 'WINNING_POSITION']]}],
#   ['Bertram Kerr, your outstanding performance in the Rhythmic Gymnastics during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[50, 69, 'SPORTS_NAME'],
#      [81, 85, 'ORG_YEAR'],
#      [129, 132, 'WINNING_POSITION']]}],
#   ['Dexter Larsen, your outstanding performance in the Volleyball during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[51, 61, 'SPORTS_NAME'],
#      [73, 77, 'ORG_YEAR'],
#      [121, 124, 'WINNING_POSITION']]}],
#   ['Eldridge Harrington, your outstanding performance in the Equestrian Eventing during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[57, 76, 'SPORTS_NAME'],
#      [88, 92, 'ORG_YEAR'],
#      [136, 139, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Athletics, Jeffery Stewart has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 64, 'SPORTS_NAME'],
#      [103, 106, 'WINNING_POSITION'],
#      [123, 127, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Clifford Drake, who has made a remarkable achievement by securing the 3rd Position in the Table Tennis competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 161, 'SPORTS_NAME'],
#      [175, 180, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Surfing, Gilberto Fitzgerald has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 62, 'SPORTS_NAME'],
#      [105, 108, 'WINNING_POSITION'],
#      [125, 129, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Freestyle BMX, Hugo Blackburn has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 68, 'SPORTS_NAME'],
#      [106, 109, 'WINNING_POSITION'],
#      [126, 130, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Diving, Jerome Richards has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 61, 'SPORTS_NAME'],
#      [100, 103, 'WINNING_POSITION'],
#      [120, 124, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Table Tennis, Conrad Williams has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [106, 109, 'WINNING_POSITION'],
#      [126, 130, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Elmo Huff, who has made a remarkable achievement by securing the 1st Position in the Rhythmic Gymnastics competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[124, 127, 'WINNING_POSITION'],
#      [144, 163, 'SPORTS_NAME'],
#      [177, 182, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Skateboarding, Sheldon Dean has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 68, 'SPORTS_NAME'],
#      [104, 107, 'WINNING_POSITION'],
#      [124, 128, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Raleigh Stevens, who has made a remarkable achievement by securing the 1st Position in the Basketball competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 160, 'SPORTS_NAME'],
#      [174, 179, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Eldridge Watkins, who has made a remarkable achievement by securing the 1st Position in the Surfing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[131, 134, 'WINNING_POSITION'],
#      [151, 158, 'SPORTS_NAME'],
#      [172, 177, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Jonas Freeman, who has made a remarkable achievement by securing the 1st Position in the Artistic Gymnastics competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 167, 'SPORTS_NAME'],
#      [181, 186, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Frederick Shelton, who has made a remarkable achievement by securing the 3rd Position in the Water Polo competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[132, 135, 'WINNING_POSITION'],
#      [152, 162, 'SPORTS_NAME'],
#      [176, 181, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Rugby Sevens, Darryl Mills has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [103, 106, 'WINNING_POSITION'],
#      [123, 127, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Frederick Briggs, who has made a remarkable achievement by securing the 2nd Position in the Judo competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[131, 134, 'WINNING_POSITION'],
#      [151, 155, 'SPORTS_NAME'],
#      [169, 174, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Raleigh Dixon, who has made a remarkable achievement by securing the 3rd Position in the Sport Climbing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [154, 162, 'SPORTS_NAME'],
#      [176, 181, 'ORG_YEAR']]}],
#   ['Frederick Giles, your outstanding performance in the Skateboarding during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[53, 66, 'SPORTS_NAME'],
#      [78, 82, 'ORG_YEAR'],
#      [126, 129, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Volleyball, Lorenzo Harper has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 65, 'SPORTS_NAME'],
#      [103, 106, 'WINNING_POSITION'],
#      [123, 127, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Archery, Truman Osborne has been awarded the 3rd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 62, 'SPORTS_NAME'],
#      [100, 103, 'WINNING_POSITION'],
#      [120, 124, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Raleigh Brock, who has made a remarkable achievement by securing the 2nd Position in the Karate competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 154, 'SPORTS_NAME'],
#      [168, 173, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Karate, Arnold Olson has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 61, 'SPORTS_NAME'],
#      [97, 100, 'WINNING_POSITION'],
#      [117, 121, 'ORG_YEAR']]}],
#   ['Eldridge Lawson, your outstanding performance in the Wrestling Freestyle during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[53, 72, 'SPORTS_NAME'],
#      [84, 88, 'ORG_YEAR'],
#      [132, 135, 'WINNING_POSITION']]}],
#   ['Percy Higgins, your outstanding performance in the Rowing during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[51, 57, 'SPORTS_NAME'],
#      [69, 73, 'ORG_YEAR'],
#      [117, 120, 'WINNING_POSITION']]}],
#   ['Raleigh Knight, your outstanding performance in the Sport Climbing during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[58, 66, 'SPORTS_NAME'],
#      [78, 82, 'ORG_YEAR'],
#      [126, 129, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Frederick Bush, who has made a remarkable achievement by securing the 2nd Position in the Skateboarding competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 162, 'SPORTS_NAME'],
#      [176, 181, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Taekwondo, Kendrick Newton has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 64, 'SPORTS_NAME'],
#      [103, 106, 'WINNING_POSITION'],
#      [123, 127, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Frederick Quinn, who has made a remarkable achievement by securing the 3rd Position in the Diving competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 156, 'SPORTS_NAME'],
#      [170, 175, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Raleigh May, who has made a remarkable achievement by securing the 2nd Position in the Equestrian Dressage competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[126, 129, 'WINNING_POSITION'],
#      [146, 165, 'SPORTS_NAME'],
#      [179, 184, 'ORG_YEAR']]}],
#   ['Harvey Kennedy, your outstanding performance in the Modern Pentathlon during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[52, 69, 'SPORTS_NAME'],
#      [81, 85, 'ORG_YEAR'],
#      [129, 132, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Roland Sweeney, who has made a remarkable achievement by securing the 1st Position in the Cycling Road competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 161, 'SPORTS_NAME'],
#      [175, 180, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Bertram Combs, who has made a remarkable achievement by securing the 3rd Position in the Canoe Slalom competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 160, 'SPORTS_NAME'],
#      [174, 179, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Volleyball, Frederick Fletcher has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 65, 'SPORTS_NAME'],
#      [107, 110, 'WINNING_POSITION'],
#      [127, 131, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Percy McKinney, who has made a remarkable achievement by securing the 2nd Position in the Freestyle BMX competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 162, 'SPORTS_NAME'],
#      [176, 181, 'ORG_YEAR']]}],
#   ['Dexter Keith, your outstanding performance in the Hockey during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[50, 56, 'SPORTS_NAME'],
#      [68, 72, 'ORG_YEAR'],
#      [116, 119, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Irving Gibson, who has made a remarkable achievement by securing the 1st Position in the Athletics competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 157, 'SPORTS_NAME'],
#      [171, 176, 'ORG_YEAR']]}],
#   ['Dexter Franklin, your outstanding performance in the Hockey during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[53, 59, 'SPORTS_NAME'],
#      [71, 75, 'ORG_YEAR'],
#      [119, 122, 'WINNING_POSITION']]}]]}

# %%
type(train_data)
# Out:
# dict

# %%
# Load the Validation data (json file)

with open('../data/test_annotations.json') as fp:
  validation_data = json.load(fp)

validation_data
# Out:
# {'classes': ['ORG_YEAR', 'SPORTS_NAME', 'WINNING_POSITION'],
#  'annotations': [['We take immense pleasure in presenting this certificate to Dexter Steele, who has made a remarkable achievement by securing the 1st Position in the Baseball competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 156, 'SPORTS_NAME'],
#      [170, 175, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Beach Volleyball, Marshall Barnes has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[61, 71, 'SPORTS_NAME'],
#      [110, 113, 'WINNING_POSITION'],
#      [130, 134, 'ORG_YEAR']]}],
#   ['Clifford Lamb, your outstanding performance in the Table Tennis during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[51, 63, 'SPORTS_NAME'],
#      [75, 79, 'ORG_YEAR'],
#      [123, 126, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Bertram Jordan, who has made a remarkable achievement by securing the 1st Position in the Triathlon competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 158, 'SPORTS_NAME'],
#      [172, 177, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Clifford Boone, who has made a remarkable achievement by securing the 2nd Position in the Fencing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 156, 'SPORTS_NAME'],
#      [170, 175, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Roland Burnett, who has made a remarkable achievement by securing the 2nd Position in the Sailing competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 156, 'SPORTS_NAME'],
#      [170, 175, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Roland Sharp, who has made a remarkable achievement by securing the 3rd Position in the Triathlon competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 156, 'SPORTS_NAME'],
#      [170, 175, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Dexter Copeland, who has made a remarkable achievement by securing the 3rd Position in the Cycling Track competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[130, 133, 'WINNING_POSITION'],
#      [150, 163, 'SPORTS_NAME'],
#      [177, 182, 'ORG_YEAR']]}],
#   ['Harvey Leach, your outstanding performance in the Wrestling Greco-Roman during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[50, 71, 'SPORTS_NAME'],
#      [83, 87, 'ORG_YEAR'],
#      [131, 134, 'WINNING_POSITION']]}],
#   ['Roland Hobbs, your outstanding performance in the Sailing during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[50, 57, 'SPORTS_NAME'],
#      [69, 73, 'ORG_YEAR'],
#      [117, 120, 'WINNING_POSITION']]}],
#   ['In recognition of their exceptional performance in the Equestrian Dressage, Larry Martin has been awarded the 1st Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [110, 113, 'WINNING_POSITION'],
#      [130, 134, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Mountain Bike, Dexter Cook has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 68, 'SPORTS_NAME'],
#      [103, 106, 'WINNING_POSITION'],
#      [123, 127, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Wrestling Greco-Roman, Hugo Fox has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 76, 'SPORTS_NAME'],
#      [108, 111, 'WINNING_POSITION'],
#      [128, 132, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Bertram Walker, who has made a remarkable achievement by securing the 1st Position in the Rhythmic Gymnastics competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 168, 'SPORTS_NAME'],
#      [182, 187, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Stokes, who has made a remarkable achievement by securing the 1st Position in the BMX Cycling competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 159, 'SPORTS_NAME'],
#      [173, 178, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Harvey Coleman, who has made a remarkable achievement by securing the 3rd Position in the BMX Cycling competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[129, 132, 'WINNING_POSITION'],
#      [149, 160, 'SPORTS_NAME'],
#      [174, 179, 'ORG_YEAR']]}],
#   ['Harvey Hubbard, your outstanding performance in the Wrestling Greco-Roman during the 2013 competition has earned you a well-deserved 2nd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[52, 73, 'SPORTS_NAME'],
#      [85, 89, 'ORG_YEAR'],
#      [133, 136, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Bertram Sullivan, who has made a remarkable achievement by securing the 1st Position in the Canoe Slalom competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[131, 134, 'WINNING_POSITION'],
#      [151, 163, 'SPORTS_NAME'],
#      [177, 182, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Sport Climbing, Miles Franklin has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[61, 69, 'SPORTS_NAME'],
#      [107, 110, 'WINNING_POSITION'],
#      [127, 131, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Artistic Gymnastics, Merrill Atkins has been awarded the 3rd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [112, 115, 'WINNING_POSITION'],
#      [132, 136, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Equestrian Eventing, Clement Sullivan has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 74, 'SPORTS_NAME'],
#      [114, 117, 'WINNING_POSITION'],
#      [134, 138, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Triathlon, Bernie Wood has been awarded the 2nd Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 64, 'SPORTS_NAME'],
#      [99, 102, 'WINNING_POSITION'],
#      [119, 123, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Irving Rice, who has made a remarkable achievement by securing the 3rd Position in the Golf competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[126, 129, 'WINNING_POSITION'],
#      [146, 150, 'SPORTS_NAME'],
#      [164, 169, 'ORG_YEAR']]}],
#   ['Irving Lang, your outstanding performance in the Trampoline Gymnastics during the 2013 competition has earned you a well-deserved 3rd Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[49, 70, 'SPORTS_NAME'],
#      [82, 86, 'ORG_YEAR'],
#      [130, 133, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Percy Torres, who has made a remarkable achievement by securing the 1st Position in the Freestyle BMX competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 160, 'SPORTS_NAME'],
#      [174, 179, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Bertram Nunez, who has made a remarkable achievement by securing the 2nd Position in the Taekwondo competition, 2011. May you continue to rise and shine!\r',
#    {'entities': [[128, 131, 'WINNING_POSITION'],
#      [148, 157, 'SPORTS_NAME'],
#      [171, 176, 'ORG_YEAR']]}],
#   ['In recognition of their exceptional performance in the Canoe Slalom, Alonzo Horton has been awarded the 1st Position in the 2010 competition. We extend our hearty congratulations and best wishes for all future endeavors!\r',
#    {'entities': [[55, 67, 'SPORTS_NAME'],
#      [104, 107, 'WINNING_POSITION'],
#      [124, 128, 'ORG_YEAR']]}],
#   ['Clifford Gallagher, your outstanding performance in the Mountain Bike during the 2013 competition has earned you a well-deserved 1st Position. Your sportsmanship and zeal for the game are appreciated. Congratulations!\r',
#    {'entities': [[56, 69, 'SPORTS_NAME'],
#      [81, 85, 'ORG_YEAR'],
#      [129, 132, 'WINNING_POSITION']]}],
#   ['We take immense pleasure in presenting this certificate to Irving Burke, who has made a remarkable achievement by securing the 2nd Position in the Rugby Sevens competition, 2012. May you continue to rise and shine!\r',
#    {'entities': [[127, 130, 'WINNING_POSITION'],
#      [147, 159, 'SPORTS_NAME'],
#      [173, 178, 'ORG_YEAR']]}],
#   ['We take immense pleasure in presenting this certificate to Clifford Thornton, who has made a remarkable achievement by securing the 1st Position in the Fencing competition, 2012. May you continue to rise and shine!',
#    {'entities': [[132, 135, 'WINNING_POSITION'],
#      [152, 159, 'SPORTS_NAME'],
#      [173, 178, 'ORG_YEAR']]}]]}

# %%
# Converting train data into .spacy format

for text, annot in tqdm(train_data['annotations']): 
    doc = nlp.make_doc(text) 
    ents = []
    
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents 
    db.add(doc)

# save the docbin object
db.to_disk("training_data.spacy")
# Out:
# 100%|██████████| 268/268 [00:02<00:00, 123.76it/s]

# %%
# Converting test data into .spacy format

for text, annot in tqdm(validation_data['annotations']): 
    doc = nlp.make_doc(text) 
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents 
    db.add(doc)

# save the docbin object
db.to_disk("validation_data.spacy")
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 365.87it/s]

# %%
# Getting the config file for training

# !python -m spacy init config config.cfg --lang en --pipeline ner --optimize accuracy
# Out:
# ✘ The provided output file already exists. To force overwriting the
# config file, set the --force or -F flag.

# %%
# Training
# import os 

# os.system("python -m spacy train config.cfg --output ./ --paths.train ./training_data.spacy --paths.dev ./validation_data.spacy")

# !python -m spacy train ./config.cfg --output ./ --paths.train ./training_data.spacy --paths.dev ./validation_data.spacy
# Out:
# ^C

# %%
# Loading best model

nlp_ner = spacy.load("model-best")

# %%
text = "In recognition of their exceptional performance in the Artistic Swimming, Andrew Peterson has been awarded the 2nd Position in the 2009 competition. We extend our hearty congratulations and best wishes for all future endeavors!"

# %%
doc = nlp_ner(text)

# %%
spacy.displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In recognition of their exceptional performance in the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artistic Swimming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SPORTS_NAME</span>
# </mark>
# , Andrew Peterson has been awarded the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2nd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WINNING_POSITION</span>
# </mark>
#  Position in the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG_YEAR</span>
# </mark>
#  competition. We extend our hearty congratulations and best wishes for all future endeavors!</div></span>
